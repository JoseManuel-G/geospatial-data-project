# %%
import requests
import json
from dotenv import load_dotenv
import os
import pandas as pd

# %%
load_dotenv()
# Out:
# True

# %%
Palo_Alto = {'type': 'Point', 'coordinates': [-122.1430200, 37.4418800]}

# %%
tok1 = os.getenv("tok1")
tok2 = os.getenv("tok2")

# %%
enlace = 'https://api.foursquare.com/v2/venues/explore'

# %%
parametros = { "client_id" : 'FZIHR1CHDGDLTKY4INZF4ZWBI53251FK55IDGHGTKZX03RX4',
          "client_secret" : 'XDAHA1GTQJLEJNGQGOH5B2MRZRCEUREZEFBBOGX0PXOSM1FD',
          "v" : "20180323",
          "ll": f"{Palo_Alto.get('coordinates')[1]},{Palo_Alto.get('coordinates')[0]}",
          "query": "Sturbucks",
          "limit" : 100
}

# %%
resp = requests.get (url = enlace, params = parametros)
data = json.loads(resp.text)

# %%
data
# Out:
# {'meta': {'code': 200, 'requestId': '5fb2518e8d3f8f53d3ff303b'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': '$-$$$$', 'key': 'price'}]},
#   'suggestedRadius': 5949,
#   'headerLocation': 'Palo Alto',
#   'headerFullLocation': 'Palo Alto',
#   'headerLocationGranularity': 'city',
#   'query': 'sturbucks',
#   'totalResults': 19,
#   'suggestedBounds': {'ne': {'lat': 37.484135520168444,
#     'lng': -122.08871048605548},
#    'sw': {'lat': 37.397857260944356, 'lng': -122.21107502498509}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '598aa8702b98445795609c2b',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '1775 E Bayshore Rd',
#         'lat': 37.46012496948242,
#         'lng': -122.13626098632812,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.46012496948242,
#           'lng': -122.13626098632812}],
#         'distance': 2117,
#         'postalCode': '94303',
#         'cc': 'US',
#         'city': 'East Palo Alto',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1775 E Bayshore Rd',
#          'East Palo Alto, CA 94303',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-598aa8702b98445795609c2b-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '539f1e40498e1b0751fc5759',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '2190 West Bayshore Road',
#         'crossStreet': 'Channing Ave',
#         'lat': 37.44792674632164,
#         'lng': -122.12630178475123,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.44792674632164,
#           'lng': -122.12630178475123}],
#         'distance': 1623,
#         'postalCode': '94303',
#         'cc': 'US',
#         'city': 'Palo Alto',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['2190 West Bayshore Road (Channing Ave)',
#          'Palo Alto, CA 94303',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'delivery': {'id': '1602455',
#         'url': 'https://www.grubhub.com/restaurant/starbucks-2190-west-bayshore-road-palo-alto/1602455?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1602455',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-539f1e40498e1b0751fc5759-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a678519f964a5209ec91fe3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '1745 E Bayshore Rd',
#         'lat': 37.46154538,
#         'lng': -122.1371958,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.46154538,
#           'lng': -122.1371958},
#          {'label': 'entrance', 'lat': 37.46178, 'lng': -122.137926}],
#         'distance': 2248,
#         'postalCode': '94303',
#         'cc': 'US',
#         'city': 'East Palo Alto',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1745 E Bayshore Rd',
#          'East Palo Alto, CA 94303',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'delivery': {'id': '1631242',
#         'url': 'https://www.grubhub.com/restaurant/starbucks-1745-east-bayshore-road-east-palo-alto/1631242?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1631242',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4a678519f964a5209ec91fe3-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '49e3d406f964a520e2621fe3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '79 Stanford Mall',
#         'crossStreet': 'Quarry Rd',
#         'lat': 37.44371342096261,
#         'lng': -122.17185356460531,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.44371342096261,
#           'lng': -122.17185356460531}],
#         'distance': 2556,
#         'postalCode': '94304',
#         'cc': 'US',
#         'city': 'Palo Alto',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['79 Stanford Mall (Quarry Rd)',
#          'Palo Alto, CA 94304',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-49e3d406f964a520e2621fe3-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fc3ec73e4b0264dfd3b37cd',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '3885 El Camino Real',
#         'lat': 37.41733325,
#         'lng': -122.1306043,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.41733325,
#           'lng': -122.1306043},
#          {'label': 'entrance', 'lat': 37.417315, 'lng': -122.130612}],
#         'distance': 2944,
#         'postalCode': '94306',
#         'cc': 'US',
#         'city': 'Palo Alto',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['3885 El Camino Real',
#          'Palo Alto, CA 94306',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'delivery': {'id': '1604245',
#         'url': 'https://www.grubhub.com/restaurant/starbucks-3885-el-camino-real-palo-alto/1604245?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1604245',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4fc3ec73e4b0264dfd3b37cd-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a46602ef964a520c7a81fe3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '376 University Ave',
#         'crossStreet': 'at Waverley St',
#         'lat': 37.446737,
#         'lng': -122.1604894,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.446737,
#           'lng': -122.1604894},
#          {'label': 'entrance', 'lat': 37.446751, 'lng': -122.160626}],
#         'distance': 1635,
#         'postalCode': '94301',
#         'cc': 'US',
#         'city': 'Palo Alto',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['376 University Ave (at Waverley St)',
#          'Palo Alto, CA 94301',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'delivery': {'id': '1602440',
#         'url': 'https://www.grubhub.com/restaurant/starbucks-376-university-avenue-palo-alto/1602440?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1602440',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4a46602ef964a520c7a81fe3-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e1a3f3588777e9647822cc1',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '525 El Camino Real',
#         'crossStreet': '525 El Camino Real',
#         'lat': 37.450475,
#         'lng': -122.179198,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.450475,
#           'lng': -122.179198}],
#         'distance': 3337,
#         'postalCode': '94025',
#         'cc': 'US',
#         'city': 'Menlo Park',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['525 El Camino Real (525 El Camino Real)',
#          'Menlo Park, CA 94025',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4e1a3f3588777e9647822cc1-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '49e4f397f964a52077631fe3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '361 California Ave',
#         'lat': 37.426797,
#         'lng': -122.144019,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.426797,
#           'lng': -122.144019},
#          {'label': 'entrance', 'lat': 37.426847, 'lng': -122.144114}],
#         'distance': 1681,
#         'postalCode': '94306',
#         'cc': 'US',
#         'city': 'Palo Alto',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['361 California Ave',
#          'Palo Alto, CA 94306',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-49e4f397f964a52077631fe3-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a8dffcaf964a520b41120e3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '4131 El Camino Real',
#         'lat': 37.41310960112733,
#         'lng': -122.12524984373297,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.41310960112733,
#           'lng': -122.12524984373297},
#          {'label': 'entrance', 'lat': 37.413014, 'lng': -122.125154}],
#         'distance': 3567,
#         'postalCode': '94306',
#         'cc': 'US',
#         'city': 'Palo Alto',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['4131 El Camino Real',
#          'Palo Alto, CA 94306',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4a8dffcaf964a520b41120e3-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a89ed8ef964a520600920e3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '325 Sharon Park Dr',
#         'lat': 37.42349466188951,
#         'lng': -122.19778737875231,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.42349466188951,
#           'lng': -122.19778737875231}],
#         'distance': 5255,
#         'postalCode': '94025',
#         'cc': 'US',
#         'city': 'Menlo Park',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['325 Sharon Park Dr',
#          'Menlo Park, CA 94025',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'delivery': {'id': '1631214',
#         'url': 'https://www.grubhub.com/restaurant/starbucks-325-sharon-park-drive-menlo-park/1631214?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1631214',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4a89ed8ef964a520600920e3-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '44b28a68f964a5203d351fe3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '580 N Rengstorff Ave',
#         'lat': 37.41145353347029,
#         'lng': -122.09427251055227,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.41145353347029,
#           'lng': -122.09427251055227}],
#         'distance': 5481,
#         'postalCode': '94043',
#         'cc': 'US',
#         'city': 'Mountain View',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['580 N Rengstorff Ave',
#          'Mountain View, CA 94043',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'delivery': {'id': '1602690',
#         'url': 'https://www.grubhub.com/restaurant/starbucks-580-rengstorff-avenue-mountain-view/1602690?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1602690',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-44b28a68f964a5203d351fe3-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50351d84e4b05cd3b14e516a',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '459 Lagunita Drive',
#         'lat': 37.42438187,
#         'lng': -122.1709577,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.42438187,
#           'lng': -122.1709577}],
#         'distance': 3145,
#         'postalCode': '94305',
#         'cc': 'US',
#         'city': 'Stanford',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['459 Lagunita Drive',
#          'Stanford, CA 94305',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-50351d84e4b05cd3b14e516a-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '566f019f498e0e9d131b398f',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '2575 Sand Hill Rd',
#         'lat': 37.41987991333008,
#         'lng': -122.20551300048828,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.41987991333008,
#           'lng': -122.20551300048828}],
#         'distance': 6042,
#         'postalCode': '94025',
#         'cc': 'US',
#         'city': 'Menlo Park',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['2575 Sand Hill Rd',
#          'Menlo Park, CA 94025',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-566f019f498e0e9d131b398f-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad3bcfbf964a5200fe620e3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '2410 Charleston Rd',
#         'lat': 37.42181415384233,
#         'lng': -122.09640306829384,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.42181415384233,
#           'lng': -122.09640306829384}],
#         'distance': 4687,
#         'postalCode': '94043',
#         'cc': 'US',
#         'city': 'Mountain View',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['2410 Charleston Rd',
#          'Mountain View, CA 94043',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'delivery': {'id': '1603443',
#         'url': 'https://www.grubhub.com/restaurant/starbucks-2410-charleston-road-mountain-view/1603443?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1603443',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4ad3bcfbf964a5200fe620e3-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a1c1842f964a5200e7b1fe3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '1401 Willow Rd',
#         'lat': 37.4802137811128,
#         'lng': -122.15117406704665,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.4802137811128,
#           'lng': -122.15117406704665}],
#         'distance': 4327,
#         'postalCode': '94025',
#         'cc': 'US',
#         'city': 'Menlo Park',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1401 Willow Rd',
#          'Menlo Park, CA 94025',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'delivery': {'id': '1602075',
#         'url': 'https://www.grubhub.com/restaurant/starbucks-1401-willow-road-menlo-park/1602075?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1602075',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4a1c1842f964a5200e7b1fe3-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a57edf0f964a52018b71fe3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '643-693 Santa Cruz Ave',
#         'crossStreet': 'at Curtis St',
#         'lat': 37.452206,
#         'lng': -122.18388,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.452206,
#           'lng': -122.18388}],
#         'distance': 3789,
#         'postalCode': '94025',
#         'cc': 'US',
#         'city': 'Menlo Park',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['643-693 Santa Cruz Ave (at Curtis St)',
#          'Menlo Park, CA 94025',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'delivery': {'id': '1606327',
#         'url': 'https://www.grubhub.com/restaurant/starbucks-643-693-santa-cruz-avenue-menlo-park/1606327?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1606327',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4a57edf0f964a52018b71fe3-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5286906a498e3289da676eae',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '565 San Antonio Road',
#         'crossStreet': 'at El Camino Real',
#         'lat': 37.401779,
#         'lng': -122.111795,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.401779,
#           'lng': -122.111795},
#          {'label': 'entrance', 'lat': 37.402857, 'lng': -122.112328}],
#         'distance': 5248,
#         'postalCode': '94040',
#         'cc': 'US',
#         'city': 'Mountain View',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['565 San Antonio Road (at El Camino Real)',
#          'Mountain View, CA 94040',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'delivery': {'id': '1631628',
#         'url': 'https://www.grubhub.com/restaurant/starbucks-565-san-antonio-road-mountain-view/1631628?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1631628',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-5286906a498e3289da676eae-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a872e61f964a5201b0320e3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '995 Marsh Rd',
#         'lat': 37.478631,
#         'lng': -122.186017,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.478631,
#           'lng': -122.186017},
#          {'label': 'entrance', 'lat': 37.478515, 'lng': -122.185946}],
#         'distance': 5583,
#         'postalCode': '94063',
#         'cc': 'US',
#         'city': 'Redwood City',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['995 Marsh Rd',
#          'Redwood City, CA 94063',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'delivery': {'id': '1604104',
#         'url': 'https://www.grubhub.com/restaurant/starbucks-995-marsh-road-redwood-city/1604104?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1604104',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4a872e61f964a5201b0320e3-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a5e657bf964a5207ebe1fe3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '3590 Alameda de las Pulgas',
#         'lat': 37.43152889,
#         'lng': -122.2018663,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.43152889,
#           'lng': -122.2018663}],
#         'distance': 5327,
#         'postalCode': '94025',
#         'cc': 'US',
#         'city': 'Menlo Park',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['3590 Alameda de las Pulgas',
#          'Menlo Park, CA 94025',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'delivery': {'id': '1630769',
#         'url': 'https://www.grubhub.com/restaurant/starbucks-3590-alameda-de-las-pulgas-west-menlo-park/1630769?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1630769',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4a5e657bf964a5207ebe1fe3-18'}]}]}}

# %%
len(data)
# Out:
# 2

# %%
data.keys()
# Out:
# dict_keys(['meta', 'response'])

# %%
decoding_data = data.get("response")

# %%
decoding_data.keys()
# Out:
# dict_keys(['suggestedFilters', 'suggestedRadius', 'headerLocation', 'headerFullLocation', 'headerLocationGranularity', 'query', 'totalResults', 'suggestedBounds', 'groups'])

# %%
decoded = decoding_data.get("groups")[0]

# %%
stadium = decoded.get("items")

# %%
stadium
# Out:
# [{'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '598aa8702b98445795609c2b',
#    'name': 'Starbucks',
#    'contact': {},
#    'location': {'address': '1775 E Bayshore Rd',
#     'lat': 37.46012496948242,
#     'lng': -122.13626098632812,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.46012496948242,
#       'lng': -122.13626098632812}],
#     'distance': 2117,
#     'postalCode': '94303',
#     'cc': 'US',
#     'city': 'East Palo Alto',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['1775 E Bayshore Rd',
#      'East Palo Alto, CA 94303',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1e0931735',
#      'name': 'Coffee Shop',
#      'pluralName': 'Coffee Shops',
#      'shortName': 'Coffee Shop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': True,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'photos': {'count': 0, 'groups': []},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#   'referralId': 'e-0-598aa8702b98445795609c2b-0'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '539f1e40498e1b0751fc5759',
#    'name': 'Starbucks',
#    'contact': {},
#    'location': {'address': '2190 West Bayshore Road',
#     'crossStreet': 'Channing Ave',
#     'lat': 37.44792674632164,
#     'lng': -122.12630178475123,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.44792674632164,
#       'lng': -122.12630178475123}],
#     'distance': 1623,
#     'postalCode': '94303',
#     'cc': 'US',
#     'city': 'Palo Alto',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['2190 West Bayshore Road (Channing Ave)',
#      'Palo Alto, CA 94303',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1e0931735',
#      'name': 'Coffee Shop',
#      'pluralName': 'Coffee Shops',
#      'shortName': 'Coffee Shop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': True,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'delivery': {'id': '1602455',
#     'url': 'https://www.grubhub.com/restaurant/starbucks-2190-west-bayshore-road-palo-alto/1602455?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1602455',
#     'provider': {'name': 'grubhub',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_grubhub_20180129.png'}}},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'photos': {'count': 0, 'groups': []},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#   'referralId': 'e-0-539f1e40498e1b0751fc5759-1'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4a678519f964a5209ec91fe3',
#    'name': 'Starbucks',
#    'contact': {},
#    'location': {'address': '1745 E Bayshore Rd',
#     'lat': 37.46154538,
#     'lng': -122.1371958,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.46154538,
#       'lng': -122.1371958},
#      {'label': 'entrance', 'lat': 37.46178, 'lng': -122.137926}],
#     'distance': 2248,
#     'postalCode': '94303',
#     'cc': 'US',
#     'city': 'East Palo Alto',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['1745 E Bayshore Rd',
#      'East Palo Alto, CA 94303',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1e0931735',
#      'name': 'Coffee Shop',
#      'pluralName': 'Coffee Shops',
#      'shortName': 'Coffee Shop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': True,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'delivery': {'id': '1631242',
#     'url': 'https://www.grubhub.com/restaurant/starbucks-1745-east-bayshore-road-east-palo-alto/1631242?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1631242',
#     'provider': {'name': 'grubhub',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_grubhub_20180129.png'}}},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'photos': {'count': 0, 'groups': []},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#   'referralId': 'e-0-4a678519f964a5209ec91fe3-2'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '49e3d406f964a520e2621fe3',
#    'name': 'Starbucks',
#    'contact': {},
#    'location': {'address': '79 Stanford Mall',
#     'crossStreet': 'Quarry Rd',
#     'lat': 37.44371342096261,
#     'lng': -122.17185356460531,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.44371342096261,
#       'lng': -122.17185356460531}],
#     'distance': 2556,
#     'postalCode': '94304',
#     'cc': 'US',
#     'city': 'Palo Alto',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['79 Stanford Mall (Quarry Rd)',
#      'Palo Alto, CA 94304',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1e0931735',
#      'name': 'Coffee Shop',
#      'pluralName': 'Coffee Shops',
#      'shortName': 'Coffee Shop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': True,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'photos': {'count': 0, 'groups': []},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#   'referralId': 'e-0-49e3d406f964a520e2621fe3-3'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4fc3ec73e4b0264dfd3b37cd',
#    'name': 'Starbucks',
#    'contact': {},
#    'location': {'address': '3885 El Camino Real',
#     'lat': 37.41733325,
#     'lng': -122.1306043,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.41733325,
#       'lng': -122.1306043},
#      {'label': 'entrance', 'lat': 37.417315, 'lng': -122.130612}],
#     'distance': 2944,
#     'postalCode': '94306',
#     'cc': 'US',
#     'city': 'Palo Alto',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['3885 El Camino Real',
#      'Palo Alto, CA 94306',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1e0931735',
#      'name': 'Coffee Shop',
#      'pluralName': 'Coffee Shops',
#      'shortName': 'Coffee Shop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': True,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'delivery': {'id': '1604245',
#     'url': 'https://www.grubhub.com/restaurant/starbucks-3885-el-camino-real-palo-alto/1604245?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1604245',
#     'provider': {'name': 'grubhub',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_grubhub_20180129.png'}}},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'photos': {'count': 0, 'groups': []},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#   'referralId': 'e-0-4fc3ec73e4b0264dfd3b37cd-4'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4a46602ef964a520c7a81fe3',
#    'name': 'Starbucks',
#    'contact': {},
#    'location': {'address': '376 University Ave',
#     'crossStreet': 'at Waverley St',
#     'lat': 37.446737,
#     'lng': -122.1604894,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.446737,
#       'lng': -122.1604894},
#      {'label': 'entrance', 'lat': 37.446751, 'lng': -122.160626}],
#     'distance': 1635,
#     'postalCode': '94301',
#     'cc': 'US',
#     'city': 'Palo Alto',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['376 University Ave (at Waverley St)',
#      'Palo Alto, CA 94301',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1e0931735',
#      'name': 'Coffee Shop',
#      'pluralName': 'Coffee Shops',
#      'shortName': 'Coffee Shop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': True,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'delivery': {'id': '1602440',
#     'url': 'https://www.grubhub.com/restaurant/starbucks-376-university-avenue-palo-alto/1602440?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1602440',
#     'provider': {'name': 'grubhub',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_grubhub_20180129.png'}}},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'photos': {'count': 0, 'groups': []},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#   'referralId': 'e-0-4a46602ef964a520c7a81fe3-5'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4e1a3f3588777e9647822cc1',
#    'name': 'Starbucks',
#    'contact': {},
#    'location': {'address': '525 El Camino Real',
#     'crossStreet': '525 El Camino Real',
#     'lat': 37.450475,
#     'lng': -122.179198,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.450475,
#       'lng': -122.179198}],
#     'distance': 3337,
#     'postalCode': '94025',
#     'cc': 'US',
#     'city': 'Menlo Park',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['525 El Camino Real (525 El Camino Real)',
#      'Menlo Park, CA 94025',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1e0931735',
#      'name': 'Coffee Shop',
#      'pluralName': 'Coffee Shops',
#      'shortName': 'Coffee Shop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': True,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'photos': {'count': 0, 'groups': []},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#   'referralId': 'e-0-4e1a3f3588777e9647822cc1-6'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '49e4f397f964a52077631fe3',
#    'name': 'Starbucks',
#    'contact': {},
#    'location': {'address': '361 California Ave',
#     'lat': 37.426797,
#     'lng': -122.144019,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.426797,
#       'lng': -122.144019},
#      {'label': 'entrance', 'lat': 37.426847, 'lng': -122.144114}],
#     'distance': 1681,
#     'postalCode': '94306',
#     'cc': 'US',
#     'city': 'Palo Alto',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['361 California Ave',
#      'Palo Alto, CA 94306',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1e0931735',
#      'name': 'Coffee Shop',
#      'pluralName': 'Coffee Shops',
#      'shortName': 'Coffee Shop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': True,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'photos': {'count': 0, 'groups': []},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#   'referralId': 'e-0-49e4f397f964a52077631fe3-7'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4a8dffcaf964a520b41120e3',
#    'name': 'Starbucks',
#    'contact': {},
#    'location': {'address': '4131 El Camino Real',
#     'lat': 37.41310960112733,
#     'lng': -122.12524984373297,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.41310960112733,
#       'lng': -122.12524984373297},
#      {'label': 'entrance', 'lat': 37.413014, 'lng': -122.125154}],
#     'distance': 3567,
#     'postalCode': '94306',
#     'cc': 'US',
#     'city': 'Palo Alto',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['4131 El Camino Real',
#      'Palo Alto, CA 94306',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1e0931735',
#      'name': 'Coffee Shop',
#      'pluralName': 'Coffee Shops',
#      'shortName': 'Coffee Shop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': True,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'photos': {'count': 0, 'groups': []},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#   'referralId': 'e-0-4a8dffcaf964a520b41120e3-8'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4a89ed8ef964a520600920e3',
#    'name': 'Starbucks',
#    'contact': {},
#    'location': {'address': '325 Sharon Park Dr',
#     'lat': 37.42349466188951,
#     'lng': -122.19778737875231,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.42349466188951,
#       'lng': -122.19778737875231}],
#     'distance': 5255,
#     'postalCode': '94025',
#     'cc': 'US',
#     'city': 'Menlo Park',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['325 Sharon Park Dr',
#      'Menlo Park, CA 94025',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1e0931735',
#      'name': 'Coffee Shop',
#      'pluralName': 'Coffee Shops',
#      'shortName': 'Coffee Shop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': True,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'delivery': {'id': '1631214',
#     'url': 'https://www.grubhub.com/restaurant/starbucks-325-sharon-park-drive-menlo-park/1631214?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1631214',
#     'provider': {'name': 'grubhub',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_grubhub_20180129.png'}}},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'photos': {'count': 0, 'groups': []},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#   'referralId': 'e-0-4a89ed8ef964a520600920e3-9'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '44b28a68f964a5203d351fe3',
#    'name': 'Starbucks',
#    'contact': {},
#    'location': {'address': '580 N Rengstorff Ave',
#     'lat': 37.41145353347029,
#     'lng': -122.09427251055227,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.41145353347029,
#       'lng': -122.09427251055227}],
#     'distance': 5481,
#     'postalCode': '94043',
#     'cc': 'US',
#     'city': 'Mountain View',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['580 N Rengstorff Ave',
#      'Mountain View, CA 94043',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1e0931735',
#      'name': 'Coffee Shop',
#      'pluralName': 'Coffee Shops',
#      'shortName': 'Coffee Shop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': True,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'delivery': {'id': '1602690',
#     'url': 'https://www.grubhub.com/restaurant/starbucks-580-rengstorff-avenue-mountain-view/1602690?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1602690',
#     'provider': {'name': 'grubhub',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_grubhub_20180129.png'}}},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'photos': {'count': 0, 'groups': []},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#   'referralId': 'e-0-44b28a68f964a5203d351fe3-10'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '50351d84e4b05cd3b14e516a',
#    'name': 'Starbucks',
#    'contact': {},
#    'location': {'address': '459 Lagunita Drive',
#     'lat': 37.42438187,
#     'lng': -122.1709577,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.42438187,
#       'lng': -122.1709577}],
#     'distance': 3145,
#     'postalCode': '94305',
#     'cc': 'US',
#     'city': 'Stanford',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['459 Lagunita Drive',
#      'Stanford, CA 94305',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1e0931735',
#      'name': 'Coffee Shop',
#      'pluralName': 'Coffee Shops',
#      'shortName': 'Coffee Shop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': True,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'photos': {'count': 0, 'groups': []},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#   'referralId': 'e-0-50351d84e4b05cd3b14e516a-11'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '566f019f498e0e9d131b398f',
#    'name': 'Starbucks',
#    'contact': {},
#    'location': {'address': '2575 Sand Hill Rd',
#     'lat': 37.41987991333008,
#     'lng': -122.20551300048828,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.41987991333008,
#       'lng': -122.20551300048828}],
#     'distance': 6042,
#     'postalCode': '94025',
#     'cc': 'US',
#     'city': 'Menlo Park',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['2575 Sand Hill Rd',
#      'Menlo Park, CA 94025',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1e0931735',
#      'name': 'Coffee Shop',
#      'pluralName': 'Coffee Shops',
#      'shortName': 'Coffee Shop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': True,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'photos': {'count': 0, 'groups': []},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#   'flags': {'outsideRadius': True},
#   'referralId': 'e-0-566f019f498e0e9d131b398f-12'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4ad3bcfbf964a5200fe620e3',
#    'name': 'Starbucks',
#    'contact': {},
#    'location': {'address': '2410 Charleston Rd',
#     'lat': 37.42181415384233,
#     'lng': -122.09640306829384,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.42181415384233,
#       'lng': -122.09640306829384}],
#     'distance': 4687,
#     'postalCode': '94043',
#     'cc': 'US',
#     'city': 'Mountain View',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['2410 Charleston Rd',
#      'Mountain View, CA 94043',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1e0931735',
#      'name': 'Coffee Shop',
#      'pluralName': 'Coffee Shops',
#      'shortName': 'Coffee Shop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': True,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'delivery': {'id': '1603443',
#     'url': 'https://www.grubhub.com/restaurant/starbucks-2410-charleston-road-mountain-view/1603443?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1603443',
#     'provider': {'name': 'grubhub',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_grubhub_20180129.png'}}},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'photos': {'count': 0, 'groups': []},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#   'referralId': 'e-0-4ad3bcfbf964a5200fe620e3-13'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4a1c1842f964a5200e7b1fe3',
#    'name': 'Starbucks',
#    'contact': {},
#    'location': {'address': '1401 Willow Rd',
#     'lat': 37.4802137811128,
#     'lng': -122.15117406704665,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.4802137811128,
#       'lng': -122.15117406704665}],
#     'distance': 4327,
#     'postalCode': '94025',
#     'cc': 'US',
#     'city': 'Menlo Park',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['1401 Willow Rd',
#      'Menlo Park, CA 94025',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1e0931735',
#      'name': 'Coffee Shop',
#      'pluralName': 'Coffee Shops',
#      'shortName': 'Coffee Shop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': True,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'delivery': {'id': '1602075',
#     'url': 'https://www.grubhub.com/restaurant/starbucks-1401-willow-road-menlo-park/1602075?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1602075',
#     'provider': {'name': 'grubhub',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_grubhub_20180129.png'}}},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'photos': {'count': 0, 'groups': []},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#   'referralId': 'e-0-4a1c1842f964a5200e7b1fe3-14'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4a57edf0f964a52018b71fe3',
#    'name': 'Starbucks',
#    'contact': {},
#    'location': {'address': '643-693 Santa Cruz Ave',
#     'crossStreet': 'at Curtis St',
#     'lat': 37.452206,
#     'lng': -122.18388,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.452206,
#       'lng': -122.18388}],
#     'distance': 3789,
#     'postalCode': '94025',
#     'cc': 'US',
#     'city': 'Menlo Park',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['643-693 Santa Cruz Ave (at Curtis St)',
#      'Menlo Park, CA 94025',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1e0931735',
#      'name': 'Coffee Shop',
#      'pluralName': 'Coffee Shops',
#      'shortName': 'Coffee Shop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': True,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'delivery': {'id': '1606327',
#     'url': 'https://www.grubhub.com/restaurant/starbucks-643-693-santa-cruz-avenue-menlo-park/1606327?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1606327',
#     'provider': {'name': 'grubhub',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_grubhub_20180129.png'}}},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'photos': {'count': 0, 'groups': []},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#   'referralId': 'e-0-4a57edf0f964a52018b71fe3-15'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '5286906a498e3289da676eae',
#    'name': 'Starbucks',
#    'contact': {},
#    'location': {'address': '565 San Antonio Road',
#     'crossStreet': 'at El Camino Real',
#     'lat': 37.401779,
#     'lng': -122.111795,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.401779,
#       'lng': -122.111795},
#      {'label': 'entrance', 'lat': 37.402857, 'lng': -122.112328}],
#     'distance': 5248,
#     'postalCode': '94040',
#     'cc': 'US',
#     'city': 'Mountain View',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['565 San Antonio Road (at El Camino Real)',
#      'Mountain View, CA 94040',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1e0931735',
#      'name': 'Coffee Shop',
#      'pluralName': 'Coffee Shops',
#      'shortName': 'Coffee Shop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': True,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'delivery': {'id': '1631628',
#     'url': 'https://www.grubhub.com/restaurant/starbucks-565-san-antonio-road-mountain-view/1631628?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1631628',
#     'provider': {'name': 'grubhub',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_grubhub_20180129.png'}}},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'photos': {'count': 0, 'groups': []},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#   'referralId': 'e-0-5286906a498e3289da676eae-16'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4a872e61f964a5201b0320e3',
#    'name': 'Starbucks',
#    'contact': {},
#    'location': {'address': '995 Marsh Rd',
#     'lat': 37.478631,
#     'lng': -122.186017,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.478631,
#       'lng': -122.186017},
#      {'label': 'entrance', 'lat': 37.478515, 'lng': -122.185946}],
#     'distance': 5583,
#     'postalCode': '94063',
#     'cc': 'US',
#     'city': 'Redwood City',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['995 Marsh Rd',
#      'Redwood City, CA 94063',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1e0931735',
#      'name': 'Coffee Shop',
#      'pluralName': 'Coffee Shops',
#      'shortName': 'Coffee Shop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': True,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'delivery': {'id': '1604104',
#     'url': 'https://www.grubhub.com/restaurant/starbucks-995-marsh-road-redwood-city/1604104?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1604104',
#     'provider': {'name': 'grubhub',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_grubhub_20180129.png'}}},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'photos': {'count': 0, 'groups': []},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#   'referralId': 'e-0-4a872e61f964a5201b0320e3-17'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4a5e657bf964a5207ebe1fe3',
#    'name': 'Starbucks',
#    'contact': {},
#    'location': {'address': '3590 Alameda de las Pulgas',
#     'lat': 37.43152889,
#     'lng': -122.2018663,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.43152889,
#       'lng': -122.2018663}],
#     'distance': 5327,
#     'postalCode': '94025',
#     'cc': 'US',
#     'city': 'Menlo Park',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['3590 Alameda de las Pulgas',
#      'Menlo Park, CA 94025',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1e0931735',
#      'name': 'Coffee Shop',
#      'pluralName': 'Coffee Shops',
#      'shortName': 'Coffee Shop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': True,
#    'stats': {'tipCount': 0,
#     'usersCount': 0,
#     'checkinsCount': 0,
#     'visitsCount': 0},
#    'delivery': {'id': '1630769',
#     'url': 'https://www.grubhub.com/restaurant/starbucks-3590-alameda-de-las-pulgas-west-menlo-park/1630769?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1630769',
#     'provider': {'name': 'grubhub',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_grubhub_20180129.png'}}},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'photos': {'count': 0, 'groups': []},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#   'referralId': 'e-0-4a5e657bf964a5207ebe1fe3-18'}]
